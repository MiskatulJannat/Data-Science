# %% [markdown]
# <a href="https://colab.research.google.com/github/tuly01/Data-Science/blob/main/W2/DSE_Stock_Scrapping.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install requests-html
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
from requests_html import HTMLSession

# %%
session = HTMLSession()

# %%
url = "https://dsebd.org/old_news.php?startDate=2022-08-20&endDate=2022-08-26&criteria=4&archive=news"
r = session.get(url)
print(r.status_code)
# Out:
# 200

# %%
with open("dse_news.html", "w") as f:
  f.write(r.text)

# %%
dse_news = r.html.find(".table-news")[0].text

# %%
type(dse_news)
# Out:
# str

# %%
dse_news
# Out:
# 'Trading Code:\nMEGHNALIFE\nNews Title:\nMEGHNALIFE: Board Meeting schedule under LR 19(1)\nNews:\nAs per Regulation 19(1) of the Dhaka Stock Exchange (Listing) Regulations, 2015, the company has informed that a meeting of the Board of Directors will be held on September 04, 2022 at 4:00 PM to consider, among others, audited financial statements of the company for the year ended December 31, 2021.\nPost Date:\n2022-08-25\nTrading Code:\nEXCH\nNews Title:\nDSENEWS: Daily Turnover\nNews:\nToday\'s (25.08.2022) Total Trades: 267,596; Volume: 414,011,946 and Turnover: Tk. 17,774.527 million.\nPost Date:\n2022-08-25\nTrading Code:\nTCS\nNews Title:\nDSENEWS: Withdrawal of Authorized Representative\nNews:\nWithdrawal of Authorized Representative: Transcon Securities Limited. (DSE TREC No. 55) has withdrawn one of its Authorized Representatives, Mr. Md. Abdul Baker with immediate effect.\nPost Date:\n2022-08-25\nTrading Code:\nSSS\nNews Title:\nDSENEWS: Withdrawal of Authorized Representati
# ...

# %%
dse_news_lst = dse_news.split('\n')
trading_code = dse_news_lst[1::8]
news_title = dse_news_lst[3::8]
news = dse_news_lst[5::8]
post_date = dse_news_lst[7::8]

# %%
post_date

# %%
print(len(trading_code), len(news_title), len(news), len(post_date))
# Out:
# 196 196 196 196

# %%
with open("dse_news.txt", "w") as f:
  f.write("No, Trading Code, News Title, News, Post Date\n")
  for i, t, nt, n, p in zip(range(1, len(trading_code)+1), trading_code, news_title, news, post_date):
    f.write(f"{i}, {t}, {nt}, {n}, {p}")
    f.write('\n')

# %% [markdown]
# ## 3 month's data

# %%
June_url = "https://dsebd.org/old_news.php?startDate=2022-06-01&endDate=2022-06-30&criteria=4&archive=news"
July_url = "https://dsebd.org/old_news.php?startDate=2022-07-01&endDate=2022-07-31&criteria=4&archive=news"
August_url = "https://dsebd.org/old_news.php?startDate=2022-08-01&endDate=2022-08-31&criteria=4&archive=news"
a = session.get(June_url)
b = session.get(June_url)
c = session.get(June_url)
print(a.status_code, b.status_code, c.status_code)
# Out:
# 200 200 200

# %%
June_news = a.html.find(".table-news")[0].text
July_news = b.html.find(".table-news")[0].text
August_news = c.html.find(".table-news")[0].text

# %%
#for June
June_news_lst = June_news.split('\n')
June_trading_code = June_news_lst[1::8]
June_news_title = June_news_lst[3::8]
June_news = June_news_lst[5::8]
June_post_date = June_news_lst[7::8]
#for July
July_news_lst = July_news.split('\n')
July_trading_code = July_news_lst[1::8]
July_news_title = July_news_lst[3::8]
July_news = July_news_lst[5::8]
July_post_date = July_news_lst[7::8]
#for August
August_news_lst = August_news.split('\n')
August_trading_code = August_news_lst[1::8]
August_news_title = August_news_lst[3::8]
August_news = August_news_lst[5::8]
August_post_date = August_news_lst[7::8]

# %%
print(len(June_trading_code), len(July_news_title), len(July_news), len(August_post_date))
# Out:
# 983 983 983 983

# %%
June_trading_code

# %%
August_trading_code

# %%
with open("June.txt", "w") as f:
  f.write("No, Trading Code, News Title, News, Post Date\n")
  for i, t, nt, n, p in zip(range(1, len(June_trading_code)+1), June_trading_code, June_news_title, June_news, June_post_date):
    f.write(f"{i}, {t}, {nt}, {n}, {p}")
    f.write('\n')

# %%
with open("July.txt", "w") as f:
  f.write("No, Trading Code, News Title, News, Post Date\n")
  for i, t, nt, n, p in zip(range(1, len(July_trading_code)+1), July_trading_code, July_news_title, July_news, July_post_date):
    f.write(f"{i}, {t}, {nt}, {n}, {p}")
    f.write('\n')

# %%
with open("August.txt", "w") as f:
  f.write("No, Trading Code, News Title, News, Post Date\n")
  for i, t, nt, n, p in zip(range(1, len(August_trading_code)+1), August_trading_code, August_news_title, August_news, August_post_date):
    f.write(f"{i}, {t}, {nt}, {n}, {p}")
    f.write('\n')

# %% [markdown]
# # Optimized Code

# %%
from requests_html import HTMLSession
session = HTMLSession()
def files(m, name):
  url = f"https://dsebd.org/old_news.php?startDate=2022-0{m}-01&endDate=2022-0{m}-30&criteria=4&archive=news"
  r = session.get(url)
  dse_news = r.html.find(".table-news")[0].text
  dse_news_lst = dse_news.split('\n')
  trading_code = dse_news_lst[1::8]
  news_title = dse_news_lst[3::8]
  news = dse_news_lst[5::8]
  post_date = dse_news_lst[7::8]
  with open(f"{name}.txt", "w") as f:
    f.write("No, Trading Code, News Title, News, Post Date\n")
    for i, t, nt, n, p in zip(range(1, len(trading_code)+1), trading_code, news_title, news, post_date):
      f.write(f"{i}, {t}, {nt}, {n}, {p}")
      f.write('\n')

files(1, "January")
files(2, "February")
files(3, "March")
